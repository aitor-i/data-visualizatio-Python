# %%
import pandas as pd
import matplotlib.pyplot as plt


df = pd.read_csv("./dempgraphic_data.csv")

# %%
df.groupby("race").describe()

# %%
df["race"].value_counts()

# %%
race = pd.Series(df["race"].value_counts())

# %%
df.head()

# %%
df[["sex","age"]]

# %%
df.loc[df["sex"]=="Male",["age"]].mean()

# %%
round((len(df.loc[df["education"]=="Bachelors",["education"]])/len(df["education"]))*100,2)

# %%
high_education = (df["education"] == "Bachelors") | (df["education"] == "Masters") | (df["education"] == "Doctorate")
low_education =  (df["education"] != "Bachelors") & (df["education"] != "Masters") & (df["education"] != "Doctorate")
high_salary = df["salary"]==">50K"
low_salary = df["salary"]!=">50K"
indian = df['native-country'] == "India"

# %%
df[high_education & high_salary]

# %%
round((len(df[low_education & high_salary])/len(df)*100),2)

# %%
len(df[high_education]["salary"])

# %%
min_work_hours = df['hours-per-week'].min()
num_min_workers = len(df.loc[df['hours-per-week']== min_work_hours])
round((len(df.loc[df['hours-per-week']== min_work_hours & high_salary])/len(df))*100,2)
# Out:
# 0.01

# %%
df.loc[high_salary]['native-country'].value_counts()
# Out:
# United-States         7171
# ?                      146
# Philippines             61
# Germany                 44
# India                   40
# Canada                  39
# Mexico                  33
# England                 30
# Italy                   25
# Cuba                    25
# Japan                   24
# China                   20
# Taiwan                  20
# Iran                    18
# South                   16
# France                  12
# Puerto-Rico             12
# Poland                  12
# Jamaica                 10
# El-Salvador              9
# Greece                   8
# Cambodia                 7
# Hong                     6
# Yugoslavia               6
# Vietnam                  5
# Ireland                  5
# Haiti                    4
# Ecuador                  4
# Portugal                 4
# Hungary                  3
# Thailand                 3
# Scotland                 3
# Guatemala                3
# Dominican-Republic       2
# ...

# %%
highest_earning_country = df.loc[high_salary]['native-country'].value_counts()[0]
highest_earning_country
# Out:
# 7171

# %%
round((highest_earning_country/len(df.loc[high_salary]))*100,2)
# Out:
# 91.46

# %%
df.loc[high_salary & indian]['occupation'].value_counts().idxmax()
# Out:
# 'Prof-specialty'

# %%
round(df.loc[df["sex"]=="Male",["age"]].mean(),2)
# Out:
# age    39.43
# dtype: float64

# %%
round(df.loc[df["sex"]=="Male",["age"]].mean()[0],1)
# Out:
# 39.4

# %%
round((len(df[high_education & high_salary])/len(df[high_education])*100),1)
#len(df[high_education & high_salary])
# Out:
# 46.5

# %%
round((df.loc[high_salary]['native-country'].value_counts()/df['native-country'].value_counts())*100,1).idxmax()
# Out:
# 'Iran'

# %%
round((df.loc[high_salary]['native-country'].value_counts()/df['native-country'].value_counts())*100,1).max()
# Out:
# 41.9

# %%
round((df.loc[high_salary]['native-country'].value_counts()/df['native-country'].value_counts())*100,1)

# %%
round((len(df[high_education & high_salary])/len(df)*100),1)
# Out:
# 10.7

# %%
 round((len(df.loc[df['hours-per-week']== min_work_hours & high_salary])/len(df))*100,1)
# Out:
# 0.0

# %%
round((len(df['hours-per-week']== (min_work_hours & high_salary))/len(df['hours-per-week']== min_work_hours))*100,1)
# Out:
# 100.0

# %%
df.loc[df[low_education]]
